# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df=pd.read_csv("Housing.csv")

plt.scatter(df['price'],df['area'])
plt.xlabel("price")
plt.ylabel("Price")
plt.show()

X=df.iloc[:,0:1]
y=df.iloc[:,-1]

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)

y_pred=lr.predict(X_test)
y_pred

lr.predict(X_test.iloc[1].values.reshape(1,1))

plt.scatter(df['price'],df['area'])
plt.plot(X_train,lr.predict(X_train),color="red")
plt.xlabel("PRICE")
plt.ylabel("PRICE")
plt.show()

m=lr.coef_
b=lr.intercept_
#y= mx + b

y= m*13300000 + b
print(y)
# Out:
# C:\Users\harsh\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [10519.97046528]
